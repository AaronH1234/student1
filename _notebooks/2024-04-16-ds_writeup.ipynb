# %% [markdown]
# ---
# title: Data structure writeup
# toc: true
# comments: true
# layout: post
# description: GitHub Issues
# type: hacks
# courses: {compsci: {'week': 30}}
# ---

# %% [markdown]
# ## Writeup
# ### Collections
# Blog Python Model code and SQLite Database.
#
# - From VSCode using SQLite3 Editor, show your unique collection/table in database, display rows and columns in the table of the SQLite database.
#     - This shows that the SQLite3 table is working
#     - name, uid, password
#
# <img src = "https://i.ibb.co/pyBkyzf/image.png">
#
#
# - From VSCode model, show your unique code that was created to initialize table and create test data.
#     - u5 is the test data I created on 04/16.
#
# <img src = "https://i.ibb.co/8d0bdtk/image.png">
#
# ### Lists and Dictionaries
# Blog Python API code and use of List and Dictionaries.
#
# - In VSCode using Debugger, show a list as extracted from database as Python objects.
#     - At the left side, there is a list of user. The GET request sent to the backend
#
# <img src = "https://i.ibb.co/qBnQ4yQ/image.png">
#
# - In VSCode use Debugger and list, show two distinct example examples of dictionaries, show Keys/Values using debugger.
#     - After the user is fetch, it is stored as a dictionary.
#     - When the frontend sends the data such as name and uid, the back will store it.
#
# <img src = "https://i.ibb.co/DbfqKKZ/image.png">
#
# ### APIs and JSON
# Blog Python API code and use of Postman to request and respond with JSON.
#
# - In VSCode, show Python API code definition for request and response using GET, POST, UPDATE methods. Discuss algorithmic condition used to direct request to appropriate Python method based on request method.
#     - Picture below shows the POST and the GET method
#
# <img src = "https://i.ibb.co/YdDJp4G/image.png">
#
# <img src = "https://i.ibb.co/ZzLfnss/image.png">
#
# - In VSCode, show algorithmic conditions used to validate data on a POST condition.
#     - The len method ensure that the length of the username and the uid should be longer that 2 characters.
#
# <img src = "https://i.ibb.co/zbQ4nMk/image.png">
#
# - In Postman, show URL request and Body requirements for GET, POST, and UPDATE methods.
#
# - In Postman, show the JSON response data for 200 success conditions on GET, POST, and UPDATE methods.
# <img src = "https://i.ibb.co/B2fXVPS/image.png">
#
# <img src = "https://i.ibb.co/4TDbXqm/image.png">
#
#
#
# - In Postman, show the JSON response for error for 400 when missing body on a POST request.
# <img src = "https://i.ibb.co/Lnth9vW/image.png">
#
# - In Postman, show the JSON response for error for 404 when providing an unknown user ID to a UPDATE request.
# <img src = "https://i.ibb.co/NVTFLB6/image.png">
#
# <img src = "https://i.ibb.co/d41KKNc/image.png">
#
# ### Frontend
# Blog JavaScript API fetch code and formatting code to display JSON.
#
# - In Chrome inspect, show response of JSON objects from fetch of GET, POST, and UPDATE methods.
#     - GET methods
#
#     <img src = "https://i.ibb.co/LgtWV0H/image.png">
#
#     - POST methods
#
#     <img src = "https://i.ibb.co/8rq5Nmc/image.png">
#
# - In the Chrome browser, show a demo (GET) of obtaining an Array of JSON objects that are formatted into the browsers screen.
#     - In JavaScript code, describe fetch and method that obtained the Array of JSON objects.
#     <img src = "https://i.ibb.co/DRKRF5F/image.png">
#
#     - In JavaScript code, show code that performs iteration and formatting of data into HTML.
#         - The fetch code connect the backend and the frontend so when the user send, the backend will get the data.
#         - After that, the the frontend will get the data from backend and show it on the webpage.
#
#     <img src = "https://i.ibb.co/QHZBLBf/image.png">
#
#
#
# - In the Chrome browser, show a demo (POST or UPDATE) gathering and sending input and receiving a response that show update. Repeat this demo showing both success and failure.
#     - In JavaScript code, show and describe code that handles success. Describe how code shows success to the user in the Chrome Browser screen.
#         - In Chrome, it shows that the code works.
#
#     - <img src = "https://i.ibb.co/3WNbYcg/image.png">
#
#         - In the code, when it response ok, then  the chorme will shows that Login Successful and the change to next page.
#
#     <img src = "https://i.ibb.co/dLCDNc6/image.png">
#
#     -  JavaScript code, show and describe code that handles failure. Describe how the code shows failure to the user in the Chrome Browser screen.
#         - If user enter wrong password or wrong uid, then in the Chrome Browser screen, it will shows an error and users can not login to our page.
#         - If user enter a username that isn't signup first, it will also shows an error.
#
#     <img src = "https://i.ibb.co/yFjNvyD/image.png">
#     <img src = "https://i.ibb.co/zSgXpfr/image.png">
#
# ### Notes
# - Python CORS
#     - Move the cors code to the _init_.py but not in main.py
# - Python authentication
#     - @token_required is used to guard HTTP endpoints.
#
# - Need to include options in the fetch code and need to import to every fetch code to other projects.
#
# - The @token_required ensures that the user is authenticated before they can access the data.
# - The underscore (_) indicates that the current_user is not used in this method.
#
# - Docker
#     - Change the port
#     - Server name
